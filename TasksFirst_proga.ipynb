# %% [markdown]
# <a href="https://colab.research.google.com/github/Vladislav260908/University/blob/main/TasksFirst_proga.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
print('Hello MIIGAIK')
# Out:
# Hello World
